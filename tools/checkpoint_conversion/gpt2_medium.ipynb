# %%
# !pip install transformers --quiet
# !pip install git+https://github.com/abheesht17/keras-nlp.git@gpt-2-weights tensorflow tensorflow-text --upgrade --quiet
# Out:
#      |████████████████████████████████| 4.9 MB 19.0 MB/s
#      |████████████████████████████████| 120 kB 70.6 MB/s
#      |████████████████████████████████| 6.6 MB 59.4 MB/s
#      |████████████████████████████████| 578.0 MB 17 kB/s
#      |████████████████████████████████| 5.9 MB 35.0 MB/s
#      |████████████████████████████████| 5.9 MB 62.0 MB/s
#      |████████████████████████████████| 1.7 MB 66.3 MB/s
#      |████████████████████████████████| 438 kB 50.4 MB/s
#   Building wheel for keras-nlp (setup.py) ... done

# %%
# Let's fetch the BPE Tokenizer class from Jesse's branch.
# !wget https://raw.githubusercontent.com/keras-team/keras-nlp/66c013cee666874e06f05da37191d70d08840a90/keras_nlp/tokenizers/byte_pair_tokenizer.py
# Out:
# --2022-09-17 17:12:18--  https://raw.githubusercontent.com/keras-team/keras-nlp/66c013cee666874e06f05da37191d70d08840a90/keras_nlp/tokenizers/byte_pair_tokenizer.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14600 (14K) [text/plain]
# Saving to: ‘byte_pair_tokenizer.py’
#
# byte_pair_tokenizer 100%[===================>]  14.26K  --.-KB/s    in 0s
#
# 2022-09-17 17:12:18 (81.4 MB/s) - ‘byte_pair_tokenizer.py’ saved [14600/14600]

# %%
import sys
sys.path.append("./")

import json
import os

import keras_nlp
import numpy as np

import tensorflow as tf
from tensorflow import keras

import torch

from transformers import AutoTokenizer, AutoModel

from byte_pair_tokenizer import BytePairTokenizer

tf.__version__
# Out:
# '2.10.0'

# %%
# Variables.

# Should be one of 124M, 355M, 774M, 1558M.
NUM_PARAMS = "355M"

# %%
# Let's get the official OpenAI GPT-2 ckpt.

# !wget https://raw.githubusercontent.com/openai/gpt-2/master/download_model.py
# !python3 download_model.py $NUM_PARAMS
# Out:
# --2022-09-17 17:12:24--  https://raw.githubusercontent.com/openai/gpt-2/master/download_model.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1075 (1.0K) [text/plain]
# Saving to: ‘download_model.py’
#
# download_model.py   100%[===================>]   1.05K  --.-KB/s    in 0s
#
# 2022-09-17 17:12:24 (54.5 MB/s) - ‘download_model.py’ saved [1075/1075]
#
# Fetching checkpoint: 1.00kit [00:00, 972kit/s]
# Fetching encoder.json: 1.04Mit [00:01, 623kit/s]
# Fetching hparams.json: 1.00kit [00:00, 747kit/s]
# Fetching model.ckpt.data-00000-of-00001: 1.42Git [03:50, 6.16Mit/s]
# Fetching model.ckpt.index: 11.0kit [00:00, 9.13Mit/s]
# Fetching model.ckpt.meta: 927kit [00:01, 551kit/s]
# Fetching vocab.bpe: 457kit [00:01, 363kit/s]

# %%
# GPT-2 paths.
extract_dir = f"/content/models/{NUM_PARAMS}"
merges_path = os.path.join(extract_dir, "vocab.bpe")
vocab_path = os.path.join(extract_dir, "encoder.json")
checkpoint_path = os.path.join(extract_dir, "model.ckpt")
config_path = os.path.join(extract_dir, "hparams.json")

# %%
# n_vocab, n_ctx, n_embd, n_head, n_layer
with open(config_path, "r") as f:
    cfg = json.load(f)

cfg
# Out:
# {'n_vocab': 50257, 'n_ctx': 1024, 'n_embd': 1024, 'n_head': 16, 'n_layer': 24}

# %%
vars = tf.train.list_variables(checkpoint_path)
weights = {}
for name, shape in vars:
    print(name, shape)
    weight = tf.train.load_variable(checkpoint_path, name)
    weights[name] = weight
# Out:
# model/h0/attn/c_attn/b [3072]
# model/h0/attn/c_attn/w [1, 1024, 3072]
# model/h0/attn/c_proj/b [1024]
# model/h0/attn/c_proj/w [1, 1024, 1024]
# model/h0/ln_1/b [1024]
# model/h0/ln_1/g [1024]
# model/h0/ln_2/b [1024]
# model/h0/ln_2/g [1024]
# model/h0/mlp/c_fc/b [4096]
# model/h0/mlp/c_fc/w [1, 1024, 4096]
# model/h0/mlp/c_proj/b [1024]
# model/h0/mlp/c_proj/w [1, 4096, 1024]
# model/h1/attn/c_attn/b [3072]
# model/h1/attn/c_attn/w [1, 1024, 3072]
# model/h1/attn/c_proj/b [1024]
# model/h1/attn/c_proj/w [1, 1024, 1024]
# model/h1/ln_1/b [1024]
# model/h1/ln_1/g [1024]
# model/h1/ln_2/b [1024]
# model/h1/ln_2/g [1024]
# model/h1/mlp/c_fc/b [4096]
# model/h1/mlp/c_fc/w [1, 1024, 4096]
# model/h1/mlp/c_proj/b [1024]
# model/h1/mlp/c_proj/w [1, 4096, 1024]
# model/h10/attn/c_attn/b [3072]
# model/h10/attn/c_attn/w [1, 1024, 3072]
# model/h10/attn/c_proj/b [1024]
# model/h10/attn/c_proj/w [1, 1024, 1024]
# model/h10/ln_1/b [1024]
# model/h10/ln_1/g [1024]
# model/h10/ln_2/b [1024]
# model/h10/ln_2/g [1024]
# model/h10/mlp/c_fc/b [4096]
# model/h10/mlp/c_fc/w [1, 1024, 4096]
# model/h10/mlp/c_proj/b [1024]
# model/h10/mlp/c_proj/w [1, 4096, 1024]
# model/h11/attn/c_attn/b [3072]
# model/h11/attn/c_attn/w [1, 1024, 3072]
# model/h11/attn/c_proj/b [1024]
# model/h11/attn/c_proj/w [1, 1024, 1024]
# model/h11/ln_1/b [1024]
# model/h11/ln_1/g [1024]
# model/h11/ln_2/b [1024]
# model/h11/ln_2/g [1024]
# model/h11/mlp/c_fc/b [4096]
# model/h11/mlp/c_fc/w [1, 1024, 4096]
# model/h11/mlp/c_proj/b [1024]
# model/h11/mlp/c_proj/w [1, 4096, 1024]
# model/h12/attn/c_attn/b [3072]
# model/h12/attn/c_attn/w [1, 1024, 3072]
# model/h12/attn/c_proj/b [1024]
# model/h12/attn/c_proj/w [1, 1024, 1024]
# model/h12/ln_1/b [1024]
# model/h12/ln_1/g [1024]
# model/h12/ln_2/b [1024]
# model/h12/ln_2/g [1024]
# model/h12/mlp/c_fc/b [4096]
# model/h12/mlp/c_fc/w [1, 1024, 4096]
# model/h12/mlp/c_proj/b [1024]
# model/h12/mlp/c_proj/w [1, 4096, 1024]
# model/h13/attn/c_attn/b [3072]
# model/h13/attn/c_attn/w [1, 1024, 3072]
# model/h13/attn/c_proj/b [1024]
# model/h13/attn/c_proj/w [1, 1024, 1024]
# model/h13/ln_1/b [1024]
# model/h13/ln_1/g [1024]
# model/h13/ln_2/b [1024]
# model/h13/ln_2/g [1024]
# model/h13/mlp/c_fc/b [4096]
# model/h13/mlp/c_fc/w [1, 1024, 4096]
# model/h13/mlp/c_proj/b [1024]
# model/h13/mlp/c_proj/w [1, 4096, 1024]
# model/h14/attn/c_attn/b [3072]
# model/h14/attn/c_attn/w [1, 1024, 3072]
# model/h14/attn/c_proj/b [1024]
# model/h14/attn/c_proj/w [1, 1024, 1024]
# model/h14/ln_1/b [1024]
# model/h14/ln_1/g [1024]
# model/h14/ln_2/b [1024]
# model/h14/ln_2/g [1024]
# model/h14/mlp/c_fc/b [4096]
# model/h14/mlp/c_fc/w [1, 1024, 4096]
# model/h14/mlp/c_proj/b [1024]
# model/h14/mlp/c_proj/w [1, 4096, 1024]
# model/h15/attn/c_attn/b [3072]
# model/h15/attn/c_attn/w [1, 1024, 3072]
# model/h15/attn/c_proj/b [1024]
# model/h15/attn/c_proj/w [1, 1024, 1024]
# model/h15/ln_1/b [1024]
# model/h15/ln_1/g [1024]
# model/h15/ln_2/b [1024]
# model/h15/ln_2/g [1024]
# model/h15/mlp/c_fc/b [4096]
# model/h15/mlp/c_fc/w [1, 1024, 4096]
# model/h15/mlp/c_proj/b [1024]
# model/h15/mlp/c_proj/w [1, 4096, 1024]
# model/h16/attn/c_attn/b [3072]
# model/h16/attn/c_attn/w [1, 1024, 3072]
# model/h16/attn/c_proj/b [1024]
# model/h16/attn/c_proj/w [1, 1024, 1024]
# model/h16/ln_1/b [1024]
# model/h16/ln_1/g [1024]
# model/h16/ln_2/b [1024]
# model/h16/ln_2/g [1024]
# model/h16/mlp/c_fc/b [4096]
# model/h16/mlp/c_fc/w [1, 1024, 4096]
# model/h16/mlp/c_proj/b [1024]
# model/h16/mlp/c_proj/w [1, 4096, 1024]
# model/h17/attn/c_attn/b [3072]
# model/h17/attn/c_attn/w [1, 1024, 3072]
# model/h17/attn/c_proj/b [1024]
# model/h17/attn/c_proj/w [1, 1024, 1024]
# model/h17/ln_1/b [1024]
# model/h17/ln_1/g [1024]
# model/h17/ln_2/b [1024]
# model/h17/ln_2/g [1024]
# model/h17/mlp/c_fc/b [4096]
# model/h17/mlp/c_fc/w [1, 1024, 4096]
# model/h17/mlp/c_proj/b [1024]
# model/h17/mlp/c_proj/w [1, 4096, 1024]
# model/h18/attn/c_attn/b [3072]
# model/h18/attn/c_attn/w [1, 1024, 3072]
# model/h18/attn/c_proj/b [1024]
# model/h18/attn/c_proj/w [1, 1024, 1024]
# model/h18/ln_1/b [1024]
# model/h18/ln_1/g [1024]
# model/h18/ln_2/b [1024]
# model/h18/ln_2/g [1024]
# model/h18/mlp/c_fc/b [4096]
# model/h18/mlp/c_fc/w [1, 1024, 4096]
# model/h18/mlp/c_proj/b [1024]
# model/h18/mlp/c_proj/w [1, 4096, 1024]
# model/h19/attn/c_attn/b [3072]
# model/h19/attn/c_attn/w [1, 1024, 3072]
# model/h19/attn/c_proj/b [1024]
# model/h19/attn/c_proj/w [1, 1024, 1024]
# model/h19/ln_1/b [1024]
# model/h19/ln_1/g [1024]
# model/h19/ln_2/b [1024]
# model/h19/ln_2/g [1024]
# model/h19/mlp/c_fc/b [4096]
# model/h19/mlp/c_fc/w [1, 1024, 4096]
# model/h19/mlp/c_proj/b [1024]
# model/h19/mlp/c_proj/w [1, 4096, 1024]
# model/h2/attn/c_attn/b [3072]
# model/h2/attn/c_attn/w [1, 1024, 3072]
# model/h2/attn/c_proj/b [1024]
# model/h2/attn/c_proj/w [1, 1024, 1024]
# model/h2/ln_1/b [1024]
# model/h2/ln_1/g [1024]
# model/h2/ln_2/b [1024]
# model/h2/ln_2/g [1024]
# model/h2/mlp/c_fc/b [4096]
# model/h2/mlp/c_fc/w [1, 1024, 4096]
# model/h2/mlp/c_proj/b [1024]
# model/h2/mlp/c_proj/w [1, 4096, 1024]
# model/h20/attn/c_attn/b [3072]
# model/h20/attn/c_attn/w [1, 1024, 3072]
# model/h20/attn/c_proj/b [1024]
# model/h20/attn/c_proj/w [1, 1024, 1024]
# model/h20/ln_1/b [1024]
# model/h20/ln_1/g [1024]
# model/h20/ln_2/b [1024]
# model/h20/ln_2/g [1024]
# model/h20/mlp/c_fc/b [4096]
# model/h20/mlp/c_fc/w [1, 1024, 4096]
# model/h20/mlp/c_proj/b [1024]
# model/h20/mlp/c_proj/w [1, 4096, 1024]
# model/h21/attn/c_attn/b [3072]
# model/h21/attn/c_attn/w [1, 1024, 3072]
# model/h21/attn/c_proj/b [1024]
# model/h21/attn/c_proj/w [1, 1024, 1024]
# model/h21/ln_1/b [1024]
# model/h21/ln_1/g [1024]
# model/h21/ln_2/b [1024]
# model/h21/ln_2/g [1024]
# model/h21/mlp/c_fc/b [4096]
# model/h21/mlp/c_fc/w [1, 1024, 4096]
# model/h21/mlp/c_proj/b [1024]
# model/h21/mlp/c_proj/w [1, 4096, 1024]
# model/h22/attn/c_attn/b [3072]
# model/h22/attn/c_attn/w [1, 1024, 3072]
# model/h22/attn/c_proj/b [1024]
# model/h22/attn/c_proj/w [1, 1024, 1024]
# model/h22/ln_1/b [1024]
# model/h22/ln_1/g [1024]
# model/h22/ln_2/b [1024]
# model/h22/ln_2/g [1024]
# model/h22/mlp/c_fc/b [4096]
# model/h22/mlp/c_fc/w [1, 1024, 4096]
# model/h22/mlp/c_proj/b [1024]
# model/h22/mlp/c_proj/w [1, 4096, 1024]
# model/h23/attn/c_attn/b [3072]
# model/h23/attn/c_attn/w [1, 1024, 3072]
# model/h23/attn/c_proj/b [1024]
# model/h23/attn/c_proj/w [1, 1024, 1024]
# model/h23/ln_1/b [1024]
# model/h23/ln_1/g [1024]
# model/h23/ln_2/b [1024]
# model/h23/ln_2/g [1024]
# model/h23/mlp/c_fc/b [4096]
# model/h23/mlp/c_fc/w [1, 1024, 4096]
# model/h23/mlp/c_proj/b [1024]
# model/h23/mlp/c_proj/w [1, 4096, 1024]
# model/h3/attn/c_attn/b [3072]
# model/h3/attn/c_attn/w [1, 1024, 3072]
# model/h3/attn/c_proj/b [1024]
# model/h3/attn/c_proj/w [1, 1024, 1024]
# model/h3/ln_1/b [1024]
# model/h3/ln_1/g [1024]
# model/h3/ln_2/b [1024]
# model/h3/ln_2/g [1024]
# model/h3/mlp/c_fc/b [4096]
# model/h3/mlp/c_fc/w [1, 1024, 4096]
# model/h3/mlp/c_proj/b [1024]
# model/h3/mlp/c_proj/w [1, 4096, 1024]
# model/h4/attn/c_attn/b [3072]
# model/h4/attn/c_attn/w [1, 1024, 3072]
# model/h4/attn/c_proj/b [1024]
# model/h4/attn/c_proj/w [1, 1024, 1024]
# model/h4/ln_1/b [1024]
# model/h4/ln_1/g [1024]
# model/h4/ln_2/b [1024]
# model/h4/ln_2/g [1024]
# model/h4/mlp/c_fc/b [4096]
# model/h4/mlp/c_fc/w [1, 1024, 4096]
# model/h4/mlp/c_proj/b [1024]
# model/h4/mlp/c_proj/w [1, 4096, 1024]
# model/h5/attn/c_attn/b [3072]
# model/h5/attn/c_attn/w [1, 1024, 3072]
# model/h5/attn/c_proj/b [1024]
# model/h5/attn/c_proj/w [1, 1024, 1024]
# model/h5/ln_1/b [1024]
# model/h5/ln_1/g [1024]
# model/h5/ln_2/b [1024]
# model/h5/ln_2/g [1024]
# model/h5/mlp/c_fc/b [4096]
# model/h5/mlp/c_fc/w [1, 1024, 4096]
# model/h5/mlp/c_proj/b [1024]
# model/h5/mlp/c_proj/w [1, 4096, 1024]
# model/h6/attn/c_attn/b [3072]
# model/h6/attn/c_attn/w [1, 1024, 3072]
# model/h6/attn/c_proj/b [1024]
# model/h6/attn/c_proj/w [1, 1024, 1024]
# model/h6/ln_1/b [1024]
# model/h6/ln_1/g [1024]
# model/h6/ln_2/b [1024]
# model/h6/ln_2/g [1024]
# model/h6/mlp/c_fc/b [4096]
# model/h6/mlp/c_fc/w [1, 1024, 4096]
# model/h6/mlp/c_proj/b [1024]
# model/h6/mlp/c_proj/w [1, 4096, 1024]
# model/h7/attn/c_attn/b [3072]
# model/h7/attn/c_attn/w [1, 1024, 3072]
# model/h7/attn/c_proj/b [1024]
# model/h7/attn/c_proj/w [1, 1024, 1024]
# model/h7/ln_1/b [1024]
# model/h7/ln_1/g [1024]
# model/h7/ln_2/b [1024]
# model/h7/ln_2/g [1024]
# model/h7/mlp/c_fc/b [4096]
# model/h7/mlp/c_fc/w [1, 1024, 4096]
# model/h7/mlp/c_proj/b [1024]
# model/h7/mlp/c_proj/w [1, 4096, 1024]
# model/h8/attn/c_attn/b [3072]
# model/h8/attn/c_attn/w [1, 1024, 3072]
# model/h8/attn/c_proj/b [1024]
# model/h8/attn/c_proj/w [1, 1024, 1024]
# model/h8/ln_1/b [1024]
# model/h8/ln_1/g [1024]
# model/h8/ln_2/b [1024]
# model/h8/ln_2/g [1024]
# model/h8/mlp/c_fc/b [4096]
# model/h8/mlp/c_fc/w [1, 1024, 4096]
# model/h8/mlp/c_proj/b [1024]
# model/h8/mlp/c_proj/w [1, 4096, 1024]
# model/h9/attn/c_attn/b [3072]
# model/h9/attn/c_attn/w [1, 1024, 3072]
# model/h9/attn/c_proj/b [1024]
# model/h9/attn/c_proj/w [1, 1024, 1024]
# model/h9/ln_1/b [1024]
# model/h9/ln_1/g [1024]
# model/h9/ln_2/b [1024]
# model/h9/ln_2/g [1024]
# model/h9/mlp/c_fc/b [4096]
# model/h9/mlp/c_fc/w [1, 1024, 4096]
# model/h9/mlp/c_proj/b [1024]
# model/h9/mlp/c_proj/w [1, 4096, 1024]
# model/ln_f/b [1024]
# model/ln_f/g [1024]
# model/wpe [1024, 1024]
# model/wte [50257, 1024]

# %%
model = keras_nlp.models.Gpt2Medium(vocabulary_size=cfg['n_vocab'])

# %%
model.summary()
# Out:
# Model: "gpt2_custom"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  token_ids (InputLayer)         [(None, None)]       0           []
#
#  token_embedding (Embedding)    (None, None, 1024)   51463168    ['token_ids[0][0]']
#
#  position_embedding (PositionEm  (None, None, 1024)  1048576     ['token_embedding[0][0]']
#  bedding)
#
#  add (Add)                      (None, None, 1024)   0           ['token_embedding[0][0]',
#                                                                   'position_embedding[0][0]']
#
#  embeddings_dropout (Dropout)   (None, None, 1024)   0           ['add[0][0]']
#
#  padding_mask (InputLayer)      [(None, None)]       0           []
#
#  transformer_layer_0 (Transform  (None, None, 1024)  12596224    ['embeddings_dropout[0][0]',
#  erDecoder)                                                       'padding_mask[0][0]']
#
#  transformer_layer_1 (Transform  (None, None, 1024)  12596224    ['transformer_layer_0[0][0]',
#  erDecoder)                                                       'padding_mask[0][0]']
#
#  transformer_layer_2 (Transform  (None, None, 1024)  12596224    ['transformer_layer_1[0][0]',
#  erDecoder)                                                       'padding_mask[0][0]']
#
#  transformer_layer_3 (Transform  (None, None, 1024)  12596224    ['transformer_layer_2[0][0]',
#  erDecoder)                                                       'padding_mask[0][0]']
#
#  transformer_layer_4 (Transform  (None, None, 1024)  12596224    ['transformer_layer_3[0][0]',
#  erDecoder)                                                       'padding_mask[0][0]']
#
#  transformer_layer_5 (Transform  (None, None, 1024)  12596224    ['transformer_layer_4[0][0]',
#  erDecoder)                                                       'padding_mask[0][0]']
#
#  transformer_layer_6 (Transform  (None, None, 1024)  12596224    ['transformer_layer_5[0][0]',
#  erDecoder)                                                       'padding_mask[0][0]']
#
#  transformer_layer_7 (Transform  (None, None, 1024)  12596224    ['transformer_layer_6[0][0]',
#  erDecoder)                                                       'padding_mask[0][0]']
#
#  transformer_layer_8 (Transform  (None, None, 1024)  12596224    ['transformer_layer_7[0][0]',
#  erDecoder)                                                       'padding_mask[0][0]']
#
#  transformer_layer_9 (Transform  (None, None, 1024)  12596224    ['transformer_layer_8[0][0]',
#  erDecoder)                                                       'padding_mask[0][0]']
#
#  transformer_layer_10 (Transfor  (None, None, 1024)  12596224    ['transformer_layer_9[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  transformer_layer_11 (Transfor  (None, None, 1024)  12596224    ['transformer_layer_10[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  transformer_layer_12 (Transfor  (None, None, 1024)  12596224    ['transformer_layer_11[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  transformer_layer_13 (Transfor  (None, None, 1024)  12596224    ['transformer_layer_12[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  transformer_layer_14 (Transfor  (None, None, 1024)  12596224    ['transformer_layer_13[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  transformer_layer_15 (Transfor  (None, None, 1024)  12596224    ['transformer_layer_14[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  transformer_layer_16 (Transfor  (None, None, 1024)  12596224    ['transformer_layer_15[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  transformer_layer_17 (Transfor  (None, None, 1024)  12596224    ['transformer_layer_16[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  transformer_layer_18 (Transfor  (None, None, 1024)  12596224    ['transformer_layer_17[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  transformer_layer_19 (Transfor  (None, None, 1024)  12596224    ['transformer_layer_18[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  transformer_layer_20 (Transfor  (None, None, 1024)  12596224    ['transformer_layer_19[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  transformer_layer_21 (Transfor  (None, None, 1024)  12596224    ['transformer_layer_20[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  transformer_layer_22 (Transfor  (None, None, 1024)  12596224    ['transformer_layer_21[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  transformer_layer_23 (Transfor  (None, None, 1024)  12596224    ['transformer_layer_22[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  layer_norm (LayerNormalization  (None, None, 1024)  2048        ['transformer_layer_23[0][0]']
#  )
#
# ==================================================================================================
# Total params: 354,823,168
# Trainable params: 354,823,168
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.get_layer("token_embedding").embeddings.assign(
    weights["model/wte"]
)
model.get_layer("position_embedding").position_embeddings.assign(
    weights["model/wpe"]
)

range_1 = (0, cfg["n_embd"])
range_2 = (cfg["n_embd"], 2 * cfg["n_embd"]) 
range_3 = (2 * cfg["n_embd"], 3 * cfg["n_embd"])


for i in range(model.num_layers):
    model.get_layer(f"transformer_layer_{i}")._self_attention_layer._query_dense.kernel.assign(
        weights[f"model/h{i}/attn/c_attn/w"][0, :, range_1[0]: range_1[1]].reshape((cfg["n_embd"], cfg["n_head"], -1))
    )
    model.get_layer(f"transformer_layer_{i}")._self_attention_layer._query_dense.bias.assign(
        weights[f"model/h{i}/attn/c_attn/b"][range_1[0]: range_1[1]].reshape((cfg["n_head"], -1))
    )
    model.get_layer(f"transformer_layer_{i}")._self_attention_layer._key_dense.kernel.assign(
        weights[f"model/h{i}/attn/c_attn/w"][0, :, range_2[0]: range_2[1]].reshape((cfg["n_embd"], cfg["n_head"], -1))
    )
    model.get_layer(f"transformer_layer_{i}")._self_attention_layer._key_dense.bias.assign(
        weights[f"model/h{i}/attn/c_attn/b"][range_2[0]: range_2[1]].reshape((cfg["n_head"], -1))
    )
    model.get_layer(f"transformer_layer_{i}")._self_attention_layer._value_dense.kernel.assign(
        weights[f"model/h{i}/attn/c_attn/w"][0, :, range_3[0]: range_3[1]].reshape((cfg["n_embd"], cfg["n_head"], -1))
    )
    model.get_layer(f"transformer_layer_{i}")._self_attention_layer._value_dense.bias.assign(
        weights[f"model/h{i}/attn/c_attn/b"][range_3[0]: range_3[1]].reshape((cfg["n_head"], -1))
    )


    model.get_layer(f"transformer_layer_{i}")._self_attention_layer._output_dense.kernel.assign(
        weights[f"model/h{i}/attn/c_proj/w"][0].reshape((cfg["n_head"], -1, cfg["n_embd"]))
    )
    model.get_layer(f"transformer_layer_{i}")._self_attention_layer._output_dense.bias.assign(
        weights[f"model/h{i}/attn/c_proj/b"]
    )


    model.get_layer(f"transformer_layer_{i}")._self_attention_layernorm.gamma.assign(
        weights[f"model/h{i}/ln_1/g"]
    )
    model.get_layer(f"transformer_layer_{i}")._self_attention_layernorm.beta.assign(
        weights[f"model/h{i}/ln_1/b"]
    )


    model.get_layer(f"transformer_layer_{i}")._feedforward_intermediate_dense.kernel.assign(
        weights[f"model/h{i}/mlp/c_fc/w"][0]
    )
    model.get_layer(f"transformer_layer_{i}")._feedforward_intermediate_dense.bias.assign(
        weights[f"model/h{i}/mlp/c_fc/b"]
    )


    model.get_layer(f"transformer_layer_{i}")._feedforward_output_dense.kernel.assign(
        weights[f"model/h{i}/mlp/c_proj/w"][0]
    )
    model.get_layer(f"transformer_layer_{i}")._feedforward_output_dense.bias.assign(
        weights[f"model/h{i}/mlp/c_proj/b"]
    )


    model.get_layer(f"transformer_layer_{i}")._feedforward_layernorm.gamma.assign(
        weights[f"model/h{i}/ln_2/g"]
    )
    model.get_layer(f"transformer_layer_{i}")._feedforward_layernorm.beta.assign(
        weights[f"model/h{i}/ln_2/b"]
    )


model.get_layer("layer_norm").gamma.assign(
    weights[f"model/ln_f/g"]
)

model.get_layer("layer_norm").beta.assign(
    weights[f"model/ln_f/b"]
)
pass

# %%
# Define KerasNLP components.

bpe_tokenizer = BytePairTokenizer(
    vocabulary=vocab_path,
    merges=merges_path,
    # sequence_length=cfg["n_ctx"]
)

# Define HF components.

hf_tokenizer = AutoTokenizer.from_pretrained("gpt2-medium")
hf_model = AutoModel.from_pretrained("gpt2-medium")
hf_model.eval()
pass
# Out:
# Downloading:   0%|          | 0.00/718 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.52G [00:00<?, ?B/s]

# %%
# KerasNLP
token_ids = bpe_tokenizer(["the quick brown fox ran, galloped and jumped."])
padding_mask = token_ids != 0

inputs = {
    "token_ids": token_ids.to_tensor(),
    "padding_mask": padding_mask.to_tensor()
}

keras_nlp_output = model.predict(inputs)

# HF
hf_inputs = hf_tokenizer(["the quick brown fox ran, galloped and jumped."], return_tensors="pt")
hf_output = hf_model(**hf_inputs).last_hidden_state
# Out:
# 1/1 [==============================] - 8s 8s/step

# %%
keras_nlp_output[0, 0, :10], hf_output[0, 0, :10]
# Out:
# (array([-0.18603998, -0.29847348, -0.36645514,  0.786773  , -0.15711385,
#         -0.18149738, -0.00163372, -0.48359686, -0.1866399 , -1.6125616 ],
#        dtype=float32),
#  tensor([-0.1860, -0.2985, -0.3665,  0.7868, -0.1571, -0.1815, -0.0016, -0.4836,
#          -0.1866, -1.6126], grad_fn=<SliceBackward0>))

# %%
np.mean(keras_nlp_output - hf_output.detach().numpy())
# Out:
# 3.0315807e-08

# %%
# Save GPT2 checkpoint.
model.save_weights(f"""gpt2_medium.h5""")

# %%
model2 = keras_nlp.models.Gpt2Medium(vocabulary_size=cfg['n_vocab'])
model2.load_weights(f"""gpt2_medium.h5""")

# %%
token_ids = bpe_tokenizer(["the quick brown fox ran, galloped and jumped."])
padding_mask = token_ids != 0

inputs = {
    "token_ids": token_ids.to_tensor(),
    "padding_mask": padding_mask.to_tensor()
}

keras_nlp_output2 = model2.predict(inputs)
# Out:
# 1/1 [==============================] - 4s 4s/step

# %%
tf.reduce_mean(keras_nlp_output - keras_nlp_output2)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.0>

# %%
# !md5sum gpt2_medium.h5
# Out:
# 580ff9b79c04fc90e6d6f47e975c5afe  gpt2_medium.h5

# %%
# Check uploaded model once added to repo
model_cloud = keras_nlp.models.Gpt2Medium(weights="gpt2_medium")
# Out:
# Downloading data from https://storage.googleapis.com/keras-nlp/models/gpt2_medium_webtext/model.h5
# 1419729400/1419729400 [==============================] - 38s 0us/step

# %%
# Same output from cloud model
keras_nlp_output_cloud = model_cloud.predict(inputs)
tf.reduce_mean(keras_nlp_output - keras_nlp_output_cloud)
# Out:
# 1/1 [==============================] - 4s 4s/step
# <tf.Tensor: shape=(), dtype=float32, numpy=0.0>

# %%
keras_nlp_output_cloud[0, 0, :10]
# Out:
# array([-0.18603998, -0.29847348, -0.36645514,  0.786773  , -0.15711385,
#        -0.18149738, -0.00163372, -0.48359686, -0.1866399 , -1.6125616 ],
#       dtype=float32)
