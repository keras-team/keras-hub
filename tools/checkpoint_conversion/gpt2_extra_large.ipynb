# %%
# !pip install transformers --quiet
# !pip install git+https://github.com/abheesht17/keras-nlp.git@gpt2-presets tensorflow tensorflow-text --upgrade --quiet
# Out:
#      |████████████████████████████████| 4.9 MB 5.0 MB/s
#      |████████████████████████████████| 120 kB 78.9 MB/s
#      |████████████████████████████████| 6.6 MB 81.0 MB/s
#      |████████████████████████████████| 578.0 MB 15 kB/s
#      |████████████████████████████████| 5.9 MB 75.1 MB/s
#      |████████████████████████████████| 1.7 MB 57.1 MB/s
#      |████████████████████████████████| 438 kB 81.8 MB/s
#      |████████████████████████████████| 5.9 MB 78.4 MB/s
#   Building wheel for keras-nlp (setup.py) ... done

# %%
import json
import os

import keras_nlp
import numpy as np

import tensorflow as tf
from tensorflow import keras

import torch

from transformers import AutoTokenizer, AutoModel

tf.__version__
# Out:
# '2.10.0'

# %%
# Variables.

# Should be one of 124M, 355M, 774M, 1558M.
NUM_PARAMS = "1558M"

# %%
# Let's get the official OpenAI GPT-2 ckpt.

# !wget https://raw.githubusercontent.com/openai/gpt-2/master/download_model.py
# !python3 download_model.py $NUM_PARAMS
# Out:
# --2022-09-17 17:37:59--  https://raw.githubusercontent.com/openai/gpt-2/master/download_model.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1075 (1.0K) [text/plain]
# Saving to: ‘download_model.py’
#
# download_model.py   100%[===================>]   1.05K  --.-KB/s    in 0s
#
# 2022-09-17 17:37:59 (54.5 MB/s) - ‘download_model.py’ saved [1075/1075]
#
# Fetching checkpoint: 1.00kit [00:00, 881kit/s]
# Fetching encoder.json: 1.04Mit [00:00, 4.32Mit/s]
# Fetching hparams.json: 1.00kit [00:00, 1.07Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 6.23Git [02:28, 41.9Mit/s]
# Fetching model.ckpt.index: 21.0kit [00:00, 822kit/s]
# Fetching model.ckpt.meta: 1.84Mit [00:00, 6.40Mit/s]
# Fetching vocab.bpe: 457kit [00:00, 2.92Mit/s]

# %%
# GPT-2 paths.
extract_dir = f"/content/models/{NUM_PARAMS}"
merges_path = os.path.join(extract_dir, "vocab.bpe")
vocab_path = os.path.join(extract_dir, "encoder.json")
checkpoint_path = os.path.join(extract_dir, "model.ckpt")
config_path = os.path.join(extract_dir, "hparams.json")

# %%
# n_vocab, n_ctx, n_embd, n_head, n_layer
with open(config_path, "r") as f:
    cfg = json.load(f)

cfg
# Out:
# {'n_vocab': 50257, 'n_ctx': 1024, 'n_embd': 1600, 'n_head': 25, 'n_layer': 48}

# %%
vars = tf.train.list_variables(checkpoint_path)
weights = {}
for name, shape in vars:
    print(name, shape)
    weight = tf.train.load_variable(checkpoint_path, name)
    weights[name] = weight
# Out:
# model/h0/attn/c_attn/b [4800]
# model/h0/attn/c_attn/w [1, 1600, 4800]
# model/h0/attn/c_proj/b [1600]
# model/h0/attn/c_proj/w [1, 1600, 1600]
# model/h0/ln_1/b [1600]
# model/h0/ln_1/g [1600]
# model/h0/ln_2/b [1600]
# model/h0/ln_2/g [1600]
# model/h0/mlp/c_fc/b [6400]
# model/h0/mlp/c_fc/w [1, 1600, 6400]
# model/h0/mlp/c_proj/b [1600]
# model/h0/mlp/c_proj/w [1, 6400, 1600]
# model/h1/attn/c_attn/b [4800]
# model/h1/attn/c_attn/w [1, 1600, 4800]
# model/h1/attn/c_proj/b [1600]
# model/h1/attn/c_proj/w [1, 1600, 1600]
# model/h1/ln_1/b [1600]
# model/h1/ln_1/g [1600]
# model/h1/ln_2/b [1600]
# model/h1/ln_2/g [1600]
# model/h1/mlp/c_fc/b [6400]
# model/h1/mlp/c_fc/w [1, 1600, 6400]
# model/h1/mlp/c_proj/b [1600]
# model/h1/mlp/c_proj/w [1, 6400, 1600]
# model/h10/attn/c_attn/b [4800]
# model/h10/attn/c_attn/w [1, 1600, 4800]
# model/h10/attn/c_proj/b [1600]
# model/h10/attn/c_proj/w [1, 1600, 1600]
# model/h10/ln_1/b [1600]
# model/h10/ln_1/g [1600]
# model/h10/ln_2/b [1600]
# model/h10/ln_2/g [1600]
# model/h10/mlp/c_fc/b [6400]
# model/h10/mlp/c_fc/w [1, 1600, 6400]
# model/h10/mlp/c_proj/b [1600]
# model/h10/mlp/c_proj/w [1, 6400, 1600]
# model/h11/attn/c_attn/b [4800]
# model/h11/attn/c_attn/w [1, 1600, 4800]
# model/h11/attn/c_proj/b [1600]
# model/h11/attn/c_proj/w [1, 1600, 1600]
# model/h11/ln_1/b [1600]
# model/h11/ln_1/g [1600]
# model/h11/ln_2/b [1600]
# model/h11/ln_2/g [1600]
# model/h11/mlp/c_fc/b [6400]
# model/h11/mlp/c_fc/w [1, 1600, 6400]
# model/h11/mlp/c_proj/b [1600]
# model/h11/mlp/c_proj/w [1, 6400, 1600]
# model/h12/attn/c_attn/b [4800]
# model/h12/attn/c_attn/w [1, 1600, 4800]
# model/h12/attn/c_proj/b [1600]
# model/h12/attn/c_proj/w [1, 1600, 1600]
# model/h12/ln_1/b [1600]
# model/h12/ln_1/g [1600]
# model/h12/ln_2/b [1600]
# model/h12/ln_2/g [1600]
# model/h12/mlp/c_fc/b [6400]
# model/h12/mlp/c_fc/w [1, 1600, 6400]
# model/h12/mlp/c_proj/b [1600]
# model/h12/mlp/c_proj/w [1, 6400, 1600]
# model/h13/attn/c_attn/b [4800]
# model/h13/attn/c_attn/w [1, 1600, 4800]
# model/h13/attn/c_proj/b [1600]
# model/h13/attn/c_proj/w [1, 1600, 1600]
# model/h13/ln_1/b [1600]
# model/h13/ln_1/g [1600]
# model/h13/ln_2/b [1600]
# model/h13/ln_2/g [1600]
# model/h13/mlp/c_fc/b [6400]
# model/h13/mlp/c_fc/w [1, 1600, 6400]
# model/h13/mlp/c_proj/b [1600]
# model/h13/mlp/c_proj/w [1, 6400, 1600]
# model/h14/attn/c_attn/b [4800]
# model/h14/attn/c_attn/w [1, 1600, 4800]
# model/h14/attn/c_proj/b [1600]
# model/h14/attn/c_proj/w [1, 1600, 1600]
# model/h14/ln_1/b [1600]
# model/h14/ln_1/g [1600]
# model/h14/ln_2/b [1600]
# model/h14/ln_2/g [1600]
# model/h14/mlp/c_fc/b [6400]
# model/h14/mlp/c_fc/w [1, 1600, 6400]
# model/h14/mlp/c_proj/b [1600]
# model/h14/mlp/c_proj/w [1, 6400, 1600]
# model/h15/attn/c_attn/b [4800]
# model/h15/attn/c_attn/w [1, 1600, 4800]
# model/h15/attn/c_proj/b [1600]
# model/h15/attn/c_proj/w [1, 1600, 1600]
# model/h15/ln_1/b [1600]
# model/h15/ln_1/g [1600]
# model/h15/ln_2/b [1600]
# model/h15/ln_2/g [1600]
# model/h15/mlp/c_fc/b [6400]
# model/h15/mlp/c_fc/w [1, 1600, 6400]
# model/h15/mlp/c_proj/b [1600]
# model/h15/mlp/c_proj/w [1, 6400, 1600]
# model/h16/attn/c_attn/b [4800]
# model/h16/attn/c_attn/w [1, 1600, 4800]
# model/h16/attn/c_proj/b [1600]
# model/h16/attn/c_proj/w [1, 1600, 1600]
# model/h16/ln_1/b [1600]
# model/h16/ln_1/g [1600]
# model/h16/ln_2/b [1600]
# model/h16/ln_2/g [1600]
# model/h16/mlp/c_fc/b [6400]
# model/h16/mlp/c_fc/w [1, 1600, 6400]
# model/h16/mlp/c_proj/b [1600]
# model/h16/mlp/c_proj/w [1, 6400, 1600]
# model/h17/attn/c_attn/b [4800]
# model/h17/attn/c_attn/w [1, 1600, 4800]
# model/h17/attn/c_proj/b [1600]
# model/h17/attn/c_proj/w [1, 1600, 1600]
# model/h17/ln_1/b [1600]
# model/h17/ln_1/g [1600]
# model/h17/ln_2/b [1600]
# model/h17/ln_2/g [1600]
# model/h17/mlp/c_fc/b [6400]
# model/h17/mlp/c_fc/w [1, 1600, 6400]
# model/h17/mlp/c_proj/b [1600]
# model/h17/mlp/c_proj/w [1, 6400, 1600]
# model/h18/attn/c_attn/b [4800]
# model/h18/attn/c_attn/w [1, 1600, 4800]
# model/h18/attn/c_proj/b [1600]
# model/h18/attn/c_proj/w [1, 1600, 1600]
# model/h18/ln_1/b [1600]
# model/h18/ln_1/g [1600]
# model/h18/ln_2/b [1600]
# model/h18/ln_2/g [1600]
# model/h18/mlp/c_fc/b [6400]
# model/h18/mlp/c_fc/w [1, 1600, 6400]
# model/h18/mlp/c_proj/b [1600]
# model/h18/mlp/c_proj/w [1, 6400, 1600]
# model/h19/attn/c_attn/b [4800]
# model/h19/attn/c_attn/w [1, 1600, 4800]
# model/h19/attn/c_proj/b [1600]
# model/h19/attn/c_proj/w [1, 1600, 1600]
# model/h19/ln_1/b [1600]
# model/h19/ln_1/g [1600]
# model/h19/ln_2/b [1600]
# model/h19/ln_2/g [1600]
# model/h19/mlp/c_fc/b [6400]
# model/h19/mlp/c_fc/w [1, 1600, 6400]
# model/h19/mlp/c_proj/b [1600]
# model/h19/mlp/c_proj/w [1, 6400, 1600]
# model/h2/attn/c_attn/b [4800]
# model/h2/attn/c_attn/w [1, 1600, 4800]
# model/h2/attn/c_proj/b [1600]
# model/h2/attn/c_proj/w [1, 1600, 1600]
# model/h2/ln_1/b [1600]
# model/h2/ln_1/g [1600]
# model/h2/ln_2/b [1600]
# model/h2/ln_2/g [1600]
# model/h2/mlp/c_fc/b [6400]
# model/h2/mlp/c_fc/w [1, 1600, 6400]
# model/h2/mlp/c_proj/b [1600]
# model/h2/mlp/c_proj/w [1, 6400, 1600]
# model/h20/attn/c_attn/b [4800]
# model/h20/attn/c_attn/w [1, 1600, 4800]
# model/h20/attn/c_proj/b [1600]
# model/h20/attn/c_proj/w [1, 1600, 1600]
# model/h20/ln_1/b [1600]
# model/h20/ln_1/g [1600]
# model/h20/ln_2/b [1600]
# model/h20/ln_2/g [1600]
# model/h20/mlp/c_fc/b [6400]
# model/h20/mlp/c_fc/w [1, 1600, 6400]
# model/h20/mlp/c_proj/b [1600]
# model/h20/mlp/c_proj/w [1, 6400, 1600]
# model/h21/attn/c_attn/b [4800]
# model/h21/attn/c_attn/w [1, 1600, 4800]
# model/h21/attn/c_proj/b [1600]
# model/h21/attn/c_proj/w [1, 1600, 1600]
# model/h21/ln_1/b [1600]
# model/h21/ln_1/g [1600]
# model/h21/ln_2/b [1600]
# model/h21/ln_2/g [1600]
# model/h21/mlp/c_fc/b [6400]
# model/h21/mlp/c_fc/w [1, 1600, 6400]
# model/h21/mlp/c_proj/b [1600]
# model/h21/mlp/c_proj/w [1, 6400, 1600]
# model/h22/attn/c_attn/b [4800]
# model/h22/attn/c_attn/w [1, 1600, 4800]
# model/h22/attn/c_proj/b [1600]
# model/h22/attn/c_proj/w [1, 1600, 1600]
# model/h22/ln_1/b [1600]
# model/h22/ln_1/g [1600]
# model/h22/ln_2/b [1600]
# model/h22/ln_2/g [1600]
# model/h22/mlp/c_fc/b [6400]
# model/h22/mlp/c_fc/w [1, 1600, 6400]
# model/h22/mlp/c_proj/b [1600]
# model/h22/mlp/c_proj/w [1, 6400, 1600]
# model/h23/attn/c_attn/b [4800]
# model/h23/attn/c_attn/w [1, 1600, 4800]
# model/h23/attn/c_proj/b [1600]
# model/h23/attn/c_proj/w [1, 1600, 1600]
# model/h23/ln_1/b [1600]
# model/h23/ln_1/g [1600]
# model/h23/ln_2/b [1600]
# model/h23/ln_2/g [1600]
# model/h23/mlp/c_fc/b [6400]
# model/h23/mlp/c_fc/w [1, 1600, 6400]
# model/h23/mlp/c_proj/b [1600]
# model/h23/mlp/c_proj/w [1, 6400, 1600]
# model/h24/attn/c_attn/b [4800]
# model/h24/attn/c_attn/w [1, 1600, 4800]
# model/h24/attn/c_proj/b [1600]
# model/h24/attn/c_proj/w [1, 1600, 1600]
# model/h24/ln_1/b [1600]
# model/h24/ln_1/g [1600]
# model/h24/ln_2/b [1600]
# model/h24/ln_2/g [1600]
# model/h24/mlp/c_fc/b [6400]
# model/h24/mlp/c_fc/w [1, 1600, 6400]
# model/h24/mlp/c_proj/b [1600]
# model/h24/mlp/c_proj/w [1, 6400, 1600]
# model/h25/attn/c_attn/b [4800]
# model/h25/attn/c_attn/w [1, 1600, 4800]
# model/h25/attn/c_proj/b [1600]
# model/h25/attn/c_proj/w [1, 1600, 1600]
# model/h25/ln_1/b [1600]
# model/h25/ln_1/g [1600]
# model/h25/ln_2/b [1600]
# model/h25/ln_2/g [1600]
# model/h25/mlp/c_fc/b [6400]
# model/h25/mlp/c_fc/w [1, 1600, 6400]
# model/h25/mlp/c_proj/b [1600]
# model/h25/mlp/c_proj/w [1, 6400, 1600]
# model/h26/attn/c_attn/b [4800]
# model/h26/attn/c_attn/w [1, 1600, 4800]
# model/h26/attn/c_proj/b [1600]
# model/h26/attn/c_proj/w [1, 1600, 1600]
# model/h26/ln_1/b [1600]
# model/h26/ln_1/g [1600]
# model/h26/ln_2/b [1600]
# model/h26/ln_2/g [1600]
# model/h26/mlp/c_fc/b [6400]
# model/h26/mlp/c_fc/w [1, 1600, 6400]
# model/h26/mlp/c_proj/b [1600]
# model/h26/mlp/c_proj/w [1, 6400, 1600]
# model/h27/attn/c_attn/b [4800]
# model/h27/attn/c_attn/w [1, 1600, 4800]
# model/h27/attn/c_proj/b [1600]
# model/h27/attn/c_proj/w [1, 1600, 1600]
# model/h27/ln_1/b [1600]
# model/h27/ln_1/g [1600]
# model/h27/ln_2/b [1600]
# model/h27/ln_2/g [1600]
# model/h27/mlp/c_fc/b [6400]
# model/h27/mlp/c_fc/w [1, 1600, 6400]
# model/h27/mlp/c_proj/b [1600]
# model/h27/mlp/c_proj/w [1, 6400, 1600]
# model/h28/attn/c_attn/b [4800]
# model/h28/attn/c_attn/w [1, 1600, 4800]
# model/h28/attn/c_proj/b [1600]
# model/h28/attn/c_proj/w [1, 1600, 1600]
# model/h28/ln_1/b [1600]
# model/h28/ln_1/g [1600]
# model/h28/ln_2/b [1600]
# model/h28/ln_2/g [1600]
# model/h28/mlp/c_fc/b [6400]
# model/h28/mlp/c_fc/w [1, 1600, 6400]
# model/h28/mlp/c_proj/b [1600]
# model/h28/mlp/c_proj/w [1, 6400, 1600]
# model/h29/attn/c_attn/b [4800]
# model/h29/attn/c_attn/w [1, 1600, 4800]
# model/h29/attn/c_proj/b [1600]
# model/h29/attn/c_proj/w [1, 1600, 1600]
# model/h29/ln_1/b [1600]
# model/h29/ln_1/g [1600]
# model/h29/ln_2/b [1600]
# model/h29/ln_2/g [1600]
# model/h29/mlp/c_fc/b [6400]
# model/h29/mlp/c_fc/w [1, 1600, 6400]
# model/h29/mlp/c_proj/b [1600]
# model/h29/mlp/c_proj/w [1, 6400, 1600]
# model/h3/attn/c_attn/b [4800]
# model/h3/attn/c_attn/w [1, 1600, 4800]
# model/h3/attn/c_proj/b [1600]
# model/h3/attn/c_proj/w [1, 1600, 1600]
# model/h3/ln_1/b [1600]
# model/h3/ln_1/g [1600]
# model/h3/ln_2/b [1600]
# model/h3/ln_2/g [1600]
# model/h3/mlp/c_fc/b [6400]
# model/h3/mlp/c_fc/w [1, 1600, 6400]
# model/h3/mlp/c_proj/b [1600]
# model/h3/mlp/c_proj/w [1, 6400, 1600]
# model/h30/attn/c_attn/b [4800]
# model/h30/attn/c_attn/w [1, 1600, 4800]
# model/h30/attn/c_proj/b [1600]
# model/h30/attn/c_proj/w [1, 1600, 1600]
# model/h30/ln_1/b [1600]
# model/h30/ln_1/g [1600]
# model/h30/ln_2/b [1600]
# model/h30/ln_2/g [1600]
# model/h30/mlp/c_fc/b [6400]
# model/h30/mlp/c_fc/w [1, 1600, 6400]
# model/h30/mlp/c_proj/b [1600]
# model/h30/mlp/c_proj/w [1, 6400, 1600]
# model/h31/attn/c_attn/b [4800]
# model/h31/attn/c_attn/w [1, 1600, 4800]
# model/h31/attn/c_proj/b [1600]
# model/h31/attn/c_proj/w [1, 1600, 1600]
# model/h31/ln_1/b [1600]
# model/h31/ln_1/g [1600]
# model/h31/ln_2/b [1600]
# model/h31/ln_2/g [1600]
# model/h31/mlp/c_fc/b [6400]
# model/h31/mlp/c_fc/w [1, 1600, 6400]
# model/h31/mlp/c_proj/b [1600]
# model/h31/mlp/c_proj/w [1, 6400, 1600]
# model/h32/attn/c_attn/b [4800]
# model/h32/attn/c_attn/w [1, 1600, 4800]
# model/h32/attn/c_proj/b [1600]
# model/h32/attn/c_proj/w [1, 1600, 1600]
# model/h32/ln_1/b [1600]
# model/h32/ln_1/g [1600]
# model/h32/ln_2/b [1600]
# model/h32/ln_2/g [1600]
# model/h32/mlp/c_fc/b [6400]
# model/h32/mlp/c_fc/w [1, 1600, 6400]
# model/h32/mlp/c_proj/b [1600]
# model/h32/mlp/c_proj/w [1, 6400, 1600]
# model/h33/attn/c_attn/b [4800]
# model/h33/attn/c_attn/w [1, 1600, 4800]
# model/h33/attn/c_proj/b [1600]
# model/h33/attn/c_proj/w [1, 1600, 1600]
# model/h33/ln_1/b [1600]
# model/h33/ln_1/g [1600]
# model/h33/ln_2/b [1600]
# model/h33/ln_2/g [1600]
# model/h33/mlp/c_fc/b [6400]
# model/h33/mlp/c_fc/w [1, 1600, 6400]
# model/h33/mlp/c_proj/b [1600]
# model/h33/mlp/c_proj/w [1, 6400, 1600]
# model/h34/attn/c_attn/b [4800]
# model/h34/attn/c_attn/w [1, 1600, 4800]
# model/h34/attn/c_proj/b [1600]
# model/h34/attn/c_proj/w [1, 1600, 1600]
# model/h34/ln_1/b [1600]
# model/h34/ln_1/g [1600]
# model/h34/ln_2/b [1600]
# model/h34/ln_2/g [1600]
# model/h34/mlp/c_fc/b [6400]
# model/h34/mlp/c_fc/w [1, 1600, 6400]
# model/h34/mlp/c_proj/b [1600]
# model/h34/mlp/c_proj/w [1, 6400, 1600]
# model/h35/attn/c_attn/b [4800]
# model/h35/attn/c_attn/w [1, 1600, 4800]
# model/h35/attn/c_proj/b [1600]
# model/h35/attn/c_proj/w [1, 1600, 1600]
# model/h35/ln_1/b [1600]
# model/h35/ln_1/g [1600]
# model/h35/ln_2/b [1600]
# model/h35/ln_2/g [1600]
# model/h35/mlp/c_fc/b [6400]
# model/h35/mlp/c_fc/w [1, 1600, 6400]
# model/h35/mlp/c_proj/b [1600]
# model/h35/mlp/c_proj/w [1, 6400, 1600]
# model/h36/attn/c_attn/b [4800]
# model/h36/attn/c_attn/w [1, 1600, 4800]
# model/h36/attn/c_proj/b [1600]
# model/h36/attn/c_proj/w [1, 1600, 1600]
# model/h36/ln_1/b [1600]
# model/h36/ln_1/g [1600]
# model/h36/ln_2/b [1600]
# model/h36/ln_2/g [1600]
# model/h36/mlp/c_fc/b [6400]
# model/h36/mlp/c_fc/w [1, 1600, 6400]
# model/h36/mlp/c_proj/b [1600]
# model/h36/mlp/c_proj/w [1, 6400, 1600]
# model/h37/attn/c_attn/b [4800]
# model/h37/attn/c_attn/w [1, 1600, 4800]
# model/h37/attn/c_proj/b [1600]
# model/h37/attn/c_proj/w [1, 1600, 1600]
# model/h37/ln_1/b [1600]
# model/h37/ln_1/g [1600]
# model/h37/ln_2/b [1600]
# model/h37/ln_2/g [1600]
# model/h37/mlp/c_fc/b [6400]
# model/h37/mlp/c_fc/w [1, 1600, 6400]
# model/h37/mlp/c_proj/b [1600]
# model/h37/mlp/c_proj/w [1, 6400, 1600]
# model/h38/attn/c_attn/b [4800]
# model/h38/attn/c_attn/w [1, 1600, 4800]
# model/h38/attn/c_proj/b [1600]
# model/h38/attn/c_proj/w [1, 1600, 1600]
# model/h38/ln_1/b [1600]
# model/h38/ln_1/g [1600]
# model/h38/ln_2/b [1600]
# model/h38/ln_2/g [1600]
# model/h38/mlp/c_fc/b [6400]
# model/h38/mlp/c_fc/w [1, 1600, 6400]
# model/h38/mlp/c_proj/b [1600]
# model/h38/mlp/c_proj/w [1, 6400, 1600]
# model/h39/attn/c_attn/b [4800]
# model/h39/attn/c_attn/w [1, 1600, 4800]
# model/h39/attn/c_proj/b [1600]
# model/h39/attn/c_proj/w [1, 1600, 1600]
# model/h39/ln_1/b [1600]
# model/h39/ln_1/g [1600]
# model/h39/ln_2/b [1600]
# model/h39/ln_2/g [1600]
# model/h39/mlp/c_fc/b [6400]
# model/h39/mlp/c_fc/w [1, 1600, 6400]
# model/h39/mlp/c_proj/b [1600]
# model/h39/mlp/c_proj/w [1, 6400, 1600]
# model/h4/attn/c_attn/b [4800]
# model/h4/attn/c_attn/w [1, 1600, 4800]
# model/h4/attn/c_proj/b [1600]
# model/h4/attn/c_proj/w [1, 1600, 1600]
# model/h4/ln_1/b [1600]
# model/h4/ln_1/g [1600]
# model/h4/ln_2/b [1600]
# model/h4/ln_2/g [1600]
# model/h4/mlp/c_fc/b [6400]
# model/h4/mlp/c_fc/w [1, 1600, 6400]
# model/h4/mlp/c_proj/b [1600]
# model/h4/mlp/c_proj/w [1, 6400, 1600]
# model/h40/attn/c_attn/b [4800]
# model/h40/attn/c_attn/w [1, 1600, 4800]
# model/h40/attn/c_proj/b [1600]
# model/h40/attn/c_proj/w [1, 1600, 1600]
# model/h40/ln_1/b [1600]
# model/h40/ln_1/g [1600]
# model/h40/ln_2/b [1600]
# model/h40/ln_2/g [1600]
# model/h40/mlp/c_fc/b [6400]
# model/h40/mlp/c_fc/w [1, 1600, 6400]
# model/h40/mlp/c_proj/b [1600]
# model/h40/mlp/c_proj/w [1, 6400, 1600]
# model/h41/attn/c_attn/b [4800]
# model/h41/attn/c_attn/w [1, 1600, 4800]
# model/h41/attn/c_proj/b [1600]
# model/h41/attn/c_proj/w [1, 1600, 1600]
# model/h41/ln_1/b [1600]
# model/h41/ln_1/g [1600]
# model/h41/ln_2/b [1600]
# model/h41/ln_2/g [1600]
# model/h41/mlp/c_fc/b [6400]
# model/h41/mlp/c_fc/w [1, 1600, 6400]
# model/h41/mlp/c_proj/b [1600]
# model/h41/mlp/c_proj/w [1, 6400, 1600]
# model/h42/attn/c_attn/b [4800]
# model/h42/attn/c_attn/w [1, 1600, 4800]
# model/h42/attn/c_proj/b [1600]
# model/h42/attn/c_proj/w [1, 1600, 1600]
# model/h42/ln_1/b [1600]
# model/h42/ln_1/g [1600]
# model/h42/ln_2/b [1600]
# model/h42/ln_2/g [1600]
# model/h42/mlp/c_fc/b [6400]
# model/h42/mlp/c_fc/w [1, 1600, 6400]
# model/h42/mlp/c_proj/b [1600]
# model/h42/mlp/c_proj/w [1, 6400, 1600]
# model/h43/attn/c_attn/b [4800]
# model/h43/attn/c_attn/w [1, 1600, 4800]
# model/h43/attn/c_proj/b [1600]
# model/h43/attn/c_proj/w [1, 1600, 1600]
# model/h43/ln_1/b [1600]
# model/h43/ln_1/g [1600]
# model/h43/ln_2/b [1600]
# model/h43/ln_2/g [1600]
# model/h43/mlp/c_fc/b [6400]
# model/h43/mlp/c_fc/w [1, 1600, 6400]
# model/h43/mlp/c_proj/b [1600]
# model/h43/mlp/c_proj/w [1, 6400, 1600]
# model/h44/attn/c_attn/b [4800]
# model/h44/attn/c_attn/w [1, 1600, 4800]
# model/h44/attn/c_proj/b [1600]
# model/h44/attn/c_proj/w [1, 1600, 1600]
# model/h44/ln_1/b [1600]
# model/h44/ln_1/g [1600]
# model/h44/ln_2/b [1600]
# model/h44/ln_2/g [1600]
# model/h44/mlp/c_fc/b [6400]
# model/h44/mlp/c_fc/w [1, 1600, 6400]
# model/h44/mlp/c_proj/b [1600]
# model/h44/mlp/c_proj/w [1, 6400, 1600]
# model/h45/attn/c_attn/b [4800]
# model/h45/attn/c_attn/w [1, 1600, 4800]
# model/h45/attn/c_proj/b [1600]
# model/h45/attn/c_proj/w [1, 1600, 1600]
# model/h45/ln_1/b [1600]
# model/h45/ln_1/g [1600]
# model/h45/ln_2/b [1600]
# model/h45/ln_2/g [1600]
# model/h45/mlp/c_fc/b [6400]
# model/h45/mlp/c_fc/w [1, 1600, 6400]
# model/h45/mlp/c_proj/b [1600]
# model/h45/mlp/c_proj/w [1, 6400, 1600]
# model/h46/attn/c_attn/b [4800]
# model/h46/attn/c_attn/w [1, 1600, 4800]
# model/h46/attn/c_proj/b [1600]
# model/h46/attn/c_proj/w [1, 1600, 1600]
# model/h46/ln_1/b [1600]
# model/h46/ln_1/g [1600]
# model/h46/ln_2/b [1600]
# model/h46/ln_2/g [1600]
# model/h46/mlp/c_fc/b [6400]
# model/h46/mlp/c_fc/w [1, 1600, 6400]
# model/h46/mlp/c_proj/b [1600]
# model/h46/mlp/c_proj/w [1, 6400, 1600]
# model/h47/attn/c_attn/b [4800]
# model/h47/attn/c_attn/w [1, 1600, 4800]
# model/h47/attn/c_proj/b [1600]
# model/h47/attn/c_proj/w [1, 1600, 1600]
# model/h47/ln_1/b [1600]
# model/h47/ln_1/g [1600]
# model/h47/ln_2/b [1600]
# model/h47/ln_2/g [1600]
# model/h47/mlp/c_fc/b [6400]
# model/h47/mlp/c_fc/w [1, 1600, 6400]
# model/h47/mlp/c_proj/b [1600]
# model/h47/mlp/c_proj/w [1, 6400, 1600]
# model/h5/attn/c_attn/b [4800]
# model/h5/attn/c_attn/w [1, 1600, 4800]
# model/h5/attn/c_proj/b [1600]
# model/h5/attn/c_proj/w [1, 1600, 1600]
# model/h5/ln_1/b [1600]
# model/h5/ln_1/g [1600]
# model/h5/ln_2/b [1600]
# model/h5/ln_2/g [1600]
# model/h5/mlp/c_fc/b [6400]
# model/h5/mlp/c_fc/w [1, 1600, 6400]
# model/h5/mlp/c_proj/b [1600]
# model/h5/mlp/c_proj/w [1, 6400, 1600]
# model/h6/attn/c_attn/b [4800]
# model/h6/attn/c_attn/w [1, 1600, 4800]
# model/h6/attn/c_proj/b [1600]
# model/h6/attn/c_proj/w [1, 1600, 1600]
# model/h6/ln_1/b [1600]
# model/h6/ln_1/g [1600]
# model/h6/ln_2/b [1600]
# model/h6/ln_2/g [1600]
# model/h6/mlp/c_fc/b [6400]
# model/h6/mlp/c_fc/w [1, 1600, 6400]
# model/h6/mlp/c_proj/b [1600]
# model/h6/mlp/c_proj/w [1, 6400, 1600]
# model/h7/attn/c_attn/b [4800]
# model/h7/attn/c_attn/w [1, 1600, 4800]
# model/h7/attn/c_proj/b [1600]
# model/h7/attn/c_proj/w [1, 1600, 1600]
# model/h7/ln_1/b [1600]
# model/h7/ln_1/g [1600]
# model/h7/ln_2/b [1600]
# model/h7/ln_2/g [1600]
# model/h7/mlp/c_fc/b [6400]
# model/h7/mlp/c_fc/w [1, 1600, 6400]
# model/h7/mlp/c_proj/b [1600]
# model/h7/mlp/c_proj/w [1, 6400, 1600]
# model/h8/attn/c_attn/b [4800]
# model/h8/attn/c_attn/w [1, 1600, 4800]
# model/h8/attn/c_proj/b [1600]
# model/h8/attn/c_proj/w [1, 1600, 1600]
# model/h8/ln_1/b [1600]
# model/h8/ln_1/g [1600]
# model/h8/ln_2/b [1600]
# model/h8/ln_2/g [1600]
# model/h8/mlp/c_fc/b [6400]
# model/h8/mlp/c_fc/w [1, 1600, 6400]
# model/h8/mlp/c_proj/b [1600]
# model/h8/mlp/c_proj/w [1, 6400, 1600]
# model/h9/attn/c_attn/b [4800]
# model/h9/attn/c_attn/w [1, 1600, 4800]
# model/h9/attn/c_proj/b [1600]
# model/h9/attn/c_proj/w [1, 1600, 1600]
# model/h9/ln_1/b [1600]
# model/h9/ln_1/g [1600]
# model/h9/ln_2/b [1600]
# model/h9/ln_2/g [1600]
# model/h9/mlp/c_fc/b [6400]
# model/h9/mlp/c_fc/w [1, 1600, 6400]
# model/h9/mlp/c_proj/b [1600]
# model/h9/mlp/c_proj/w [1, 6400, 1600]
# model/ln_f/b [1600]
# model/ln_f/g [1600]
# model/wpe [1024, 1600]
# model/wte [50257, 1600]

# %%
model = keras_nlp.models.GPT2.from_preset(
    "gpt2_extra_large",
    load_weights=False,
)

# %%
model.summary()
# Out:
# Model: "gpt2_custom"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  token_ids (InputLayer)         [(None, None)]       0           []
#
#  token_embedding (Embedding)    (None, None, 1600)   80411200    ['token_ids[0][0]']
#
#  position_embedding (PositionEm  (None, None, 1600)  1638400     ['token_embedding[0][0]']
#  bedding)
#
#  add (Add)                      (None, None, 1600)   0           ['token_embedding[0][0]',
#                                                                   'position_embedding[0][0]']
#
#  embeddings_dropout (Dropout)   (None, None, 1600)   0           ['add[0][0]']
#
#  padding_mask (InputLayer)      [(None, None)]       0           []
#
#  transformer_layer_0 (Transform  (None, None, 1600)  30740800    ['embeddings_dropout[0][0]',
#  erDecoder)                                                       'padding_mask[0][0]']
#
#  transformer_layer_1 (Transform  (None, None, 1600)  30740800    ['transformer_layer_0[0][0]',
#  erDecoder)                                                       'padding_mask[0][0]']
#
#  transformer_layer_2 (Transform  (None, None, 1600)  30740800    ['transformer_layer_1[0][0]',
#  erDecoder)                                                       'padding_mask[0][0]']
#
#  transformer_layer_3 (Transform  (None, None, 1600)  30740800    ['transformer_layer_2[0][0]',
#  erDecoder)                                                       'padding_mask[0][0]']
#
#  transformer_layer_4 (Transform  (None, None, 1600)  30740800    ['transformer_layer_3[0][0]',
#  erDecoder)                                                       'padding_mask[0][0]']
#
#  transformer_layer_5 (Transform  (None, None, 1600)  30740800    ['transformer_layer_4[0][0]',
#  erDecoder)                                                       'padding_mask[0][0]']
#
#  transformer_layer_6 (Transform  (None, None, 1600)  30740800    ['transformer_layer_5[0][0]',
#  erDecoder)                                                       'padding_mask[0][0]']
#
#  transformer_layer_7 (Transform  (None, None, 1600)  30740800    ['transformer_layer_6[0][0]',
#  erDecoder)                                                       'padding_mask[0][0]']
#
#  transformer_layer_8 (Transform  (None, None, 1600)  30740800    ['transformer_layer_7[0][0]',
#  erDecoder)                                                       'padding_mask[0][0]']
#
#  transformer_layer_9 (Transform  (None, None, 1600)  30740800    ['transformer_layer_8[0][0]',
#  erDecoder)                                                       'padding_mask[0][0]']
#
#  transformer_layer_10 (Transfor  (None, None, 1600)  30740800    ['transformer_layer_9[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  transformer_layer_11 (Transfor  (None, None, 1600)  30740800    ['transformer_layer_10[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  transformer_layer_12 (Transfor  (None, None, 1600)  30740800    ['transformer_layer_11[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  transformer_layer_13 (Transfor  (None, None, 1600)  30740800    ['transformer_layer_12[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  transformer_layer_14 (Transfor  (None, None, 1600)  30740800    ['transformer_layer_13[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  transformer_layer_15 (Transfor  (None, None, 1600)  30740800    ['transformer_layer_14[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  transformer_layer_16 (Transfor  (None, None, 1600)  30740800    ['transformer_layer_15[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  transformer_layer_17 (Transfor  (None, None, 1600)  30740800    ['transformer_layer_16[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  transformer_layer_18 (Transfor  (None, None, 1600)  30740800    ['transformer_layer_17[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  transformer_layer_19 (Transfor  (None, None, 1600)  30740800    ['transformer_layer_18[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  transformer_layer_20 (Transfor  (None, None, 1600)  30740800    ['transformer_layer_19[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  transformer_layer_21 (Transfor  (None, None, 1600)  30740800    ['transformer_layer_20[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  transformer_layer_22 (Transfor  (None, None, 1600)  30740800    ['transformer_layer_21[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  transformer_layer_23 (Transfor  (None, None, 1600)  30740800    ['transformer_layer_22[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  transformer_layer_24 (Transfor  (None, None, 1600)  30740800    ['transformer_layer_23[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  transformer_layer_25 (Transfor  (None, None, 1600)  30740800    ['transformer_layer_24[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  transformer_layer_26 (Transfor  (None, None, 1600)  30740800    ['transformer_layer_25[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  transformer_layer_27 (Transfor  (None, None, 1600)  30740800    ['transformer_layer_26[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  transformer_layer_28 (Transfor  (None, None, 1600)  30740800    ['transformer_layer_27[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  transformer_layer_29 (Transfor  (None, None, 1600)  30740800    ['transformer_layer_28[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  transformer_layer_30 (Transfor  (None, None, 1600)  30740800    ['transformer_layer_29[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  transformer_layer_31 (Transfor  (None, None, 1600)  30740800    ['transformer_layer_30[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  transformer_layer_32 (Transfor  (None, None, 1600)  30740800    ['transformer_layer_31[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  transformer_layer_33 (Transfor  (None, None, 1600)  30740800    ['transformer_layer_32[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  transformer_layer_34 (Transfor  (None, None, 1600)  30740800    ['transformer_layer_33[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  transformer_layer_35 (Transfor  (None, None, 1600)  30740800    ['transformer_layer_34[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  transformer_layer_36 (Transfor  (None, None, 1600)  30740800    ['transformer_layer_35[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  transformer_layer_37 (Transfor  (None, None, 1600)  30740800    ['transformer_layer_36[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  transformer_layer_38 (Transfor  (None, None, 1600)  30740800    ['transformer_layer_37[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  transformer_layer_39 (Transfor  (None, None, 1600)  30740800    ['transformer_layer_38[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  transformer_layer_40 (Transfor  (None, None, 1600)  30740800    ['transformer_layer_39[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  transformer_layer_41 (Transfor  (None, None, 1600)  30740800    ['transformer_layer_40[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  transformer_layer_42 (Transfor  (None, None, 1600)  30740800    ['transformer_layer_41[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  transformer_layer_43 (Transfor  (None, None, 1600)  30740800    ['transformer_layer_42[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  transformer_layer_44 (Transfor  (None, None, 1600)  30740800    ['transformer_layer_43[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  transformer_layer_45 (Transfor  (None, None, 1600)  30740800    ['transformer_layer_44[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  transformer_layer_46 (Transfor  (None, None, 1600)  30740800    ['transformer_layer_45[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  transformer_layer_47 (Transfor  (None, None, 1600)  30740800    ['transformer_layer_46[0][0]',
#  merDecoder)                                                      'padding_mask[0][0]']
#
#  layer_norm (LayerNormalization  (None, None, 1600)  3200        ['transformer_layer_47[0][0]']
#  )
#
# ==================================================================================================
# Total params: 1,557,611,200
# Trainable params: 1,557,611,200
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.get_layer("token_embedding").embeddings.assign(
    weights["model/wte"]
)
model.get_layer("position_embedding").position_embeddings.assign(
    weights["model/wpe"]
)

range_1 = (0, cfg["n_embd"])
range_2 = (cfg["n_embd"], 2 * cfg["n_embd"]) 
range_3 = (2 * cfg["n_embd"], 3 * cfg["n_embd"])


for i in range(model.num_layers):
    model.get_layer(f"transformer_layer_{i}")._self_attention_layer._query_dense.kernel.assign(
        weights[f"model/h{i}/attn/c_attn/w"][0, :, range_1[0]: range_1[1]].reshape((cfg["n_embd"], cfg["n_head"], -1))
    )
    model.get_layer(f"transformer_layer_{i}")._self_attention_layer._query_dense.bias.assign(
        weights[f"model/h{i}/attn/c_attn/b"][range_1[0]: range_1[1]].reshape((cfg["n_head"], -1))
    )
    model.get_layer(f"transformer_layer_{i}")._self_attention_layer._key_dense.kernel.assign(
        weights[f"model/h{i}/attn/c_attn/w"][0, :, range_2[0]: range_2[1]].reshape((cfg["n_embd"], cfg["n_head"], -1))
    )
    model.get_layer(f"transformer_layer_{i}")._self_attention_layer._key_dense.bias.assign(
        weights[f"model/h{i}/attn/c_attn/b"][range_2[0]: range_2[1]].reshape((cfg["n_head"], -1))
    )
    model.get_layer(f"transformer_layer_{i}")._self_attention_layer._value_dense.kernel.assign(
        weights[f"model/h{i}/attn/c_attn/w"][0, :, range_3[0]: range_3[1]].reshape((cfg["n_embd"], cfg["n_head"], -1))
    )
    model.get_layer(f"transformer_layer_{i}")._self_attention_layer._value_dense.bias.assign(
        weights[f"model/h{i}/attn/c_attn/b"][range_3[0]: range_3[1]].reshape((cfg["n_head"], -1))
    )


    model.get_layer(f"transformer_layer_{i}")._self_attention_layer._output_dense.kernel.assign(
        weights[f"model/h{i}/attn/c_proj/w"][0].reshape((cfg["n_head"], -1, cfg["n_embd"]))
    )
    model.get_layer(f"transformer_layer_{i}")._self_attention_layer._output_dense.bias.assign(
        weights[f"model/h{i}/attn/c_proj/b"]
    )


    model.get_layer(f"transformer_layer_{i}")._self_attention_layernorm.gamma.assign(
        weights[f"model/h{i}/ln_1/g"]
    )
    model.get_layer(f"transformer_layer_{i}")._self_attention_layernorm.beta.assign(
        weights[f"model/h{i}/ln_1/b"]
    )


    model.get_layer(f"transformer_layer_{i}")._feedforward_intermediate_dense.kernel.assign(
        weights[f"model/h{i}/mlp/c_fc/w"][0]
    )
    model.get_layer(f"transformer_layer_{i}")._feedforward_intermediate_dense.bias.assign(
        weights[f"model/h{i}/mlp/c_fc/b"]
    )


    model.get_layer(f"transformer_layer_{i}")._feedforward_output_dense.kernel.assign(
        weights[f"model/h{i}/mlp/c_proj/w"][0]
    )
    model.get_layer(f"transformer_layer_{i}")._feedforward_output_dense.bias.assign(
        weights[f"model/h{i}/mlp/c_proj/b"]
    )


    model.get_layer(f"transformer_layer_{i}")._feedforward_layernorm.gamma.assign(
        weights[f"model/h{i}/ln_2/g"]
    )
    model.get_layer(f"transformer_layer_{i}")._feedforward_layernorm.beta.assign(
        weights[f"model/h{i}/ln_2/b"]
    )


model.get_layer("layer_norm").gamma.assign(
    weights[f"model/ln_f/g"]
)

model.get_layer("layer_norm").beta.assign(
    weights[f"model/ln_f/b"]
)
pass

# %%
# Define KerasNLP components.

gpt2_tokenizer = keras_nlp.models.GPT2Tokenizer(
    vocabulary=vocab_path,
    merges=merges_path,
    # sequence_length=cfg["n_ctx"]
)

# Define HF components.

hf_tokenizer = AutoTokenizer.from_pretrained("gpt2-xl")
hf_model = AutoModel.from_pretrained("gpt2-xl")
hf_model.eval()
pass
# Out:
# Downloading:   0%|          | 0.00/689 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/6.43G [00:00<?, ?B/s]

# %%
# KerasNLP
token_ids = gpt2_tokenizer(["the quick brown fox ran, galloped and jumped."])
padding_mask = token_ids != 0

inputs = {
    "token_ids": token_ids.to_tensor(),
    "padding_mask": padding_mask.to_tensor()
}

keras_nlp_output = model.predict(inputs)

# HF
hf_inputs = hf_tokenizer(["the quick brown fox ran, galloped and jumped."], return_tensors="pt")
hf_output = hf_model(**hf_inputs).last_hidden_state
# Out:
# 1/1 [==============================] - 10s 10s/step

# %%
keras_nlp_output[0, 0, :10], hf_output[0, 0, :10]
# Out:
# (array([-0.26750785,  0.22396186, -0.05913803, -0.12199795, -0.30013862,
#         -0.12183367, -0.5269151 ,  0.68675554,  1.8155214 , -0.2948038 ],
#        dtype=float32),
#  tensor([-0.2675,  0.2240, -0.0591, -0.1220, -0.3001, -0.1218, -0.5269,  0.6868,
#           1.8155, -0.2948], grad_fn=<SliceBackward0>))

# %%
np.mean(keras_nlp_output - hf_output.detach().numpy())
# Out:
# -1.2139675e-08

# %%
# Save GPT2 checkpoint.
model.save_weights(f"""gpt2_extra_large.h5""")

# %%
model2 = keras_nlp.models.GPT2.from_preset(
    "gpt2_extra_large",
    load_weights=False,
)
model2.load_weights(f"""gpt2_extra_large.h5""")

# %%
token_ids = gpt2_tokenizer(["the quick brown fox ran, galloped and jumped."])
padding_mask = token_ids != 0

inputs = {
    "token_ids": token_ids.to_tensor(),
    "padding_mask": padding_mask.to_tensor()
}

keras_nlp_output2 = model2.predict(inputs)
# Out:
# 1/1 [==============================] - 9s 9s/step

# %%
tf.reduce_mean(keras_nlp_output - keras_nlp_output2)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.0>

# %%
# !md5sum gpt2_extra_large.h5
# Out:
# d093c1ee0d9705d845c0190909aa2917  gpt2_extra_large.h5

# %%
# Free up some RAM :)

del model
del model2
del hf_model

# %%
# Check uploaded model once added to repo
model_cloud = keras_nlp.models.GPT2.from_preset(
    "gpt2_extra_large",
    load_weights=True,
)
# Out:
# Downloading data from https://storage.googleapis.com/keras-nlp/models/gpt2_extra_large/model.h5
# 6231301960/6231301960 [==============================] - 38s 0us/step

# %%
# Same output from cloud model
keras_nlp_output_cloud = model_cloud.predict(inputs)
tf.reduce_mean(keras_nlp_output - keras_nlp_output_cloud)
# Out:
# 1/1 [==============================] - 12s 12s/step
# <tf.Tensor: shape=(), dtype=float32, numpy=0.0>

# %%
keras_nlp_output_cloud[0, 0, :10]
# Out:
# array([-0.26750785,  0.22396186, -0.05913803, -0.12199795, -0.30013862,
#        -0.12183367, -0.5269151 ,  0.68675554,  1.8155214 , -0.2948038 ],
#       dtype=float32)
